# %%
import pandas as pd

data = pd.read_json ("data_5scheduler.json")
data
# Out:
#                                                   title   identifier  \
# 0                     Introduction to American Cultures  AMST-103-HM
# 1                            Print and American Culture  AMST-115-HM
# 2                                  Hyphenated Americans  AMST-120-HM
# 3       Life: Knowledge, Belief, and Cultural Practices  ANTH-110-HM
# 4     Introduction to the Anthropology of Science an...  ANTH-111-HM
# ...                                                 ...          ...
# 4438                           Autobiography and Memoir  WRIT-126-PZ
# 4439                          Writing the Senior Thesis  WRIT-195-PZ
# 4440                                      IGLAS Seminar  GLAS-185-PZ
# 4441                     Global Local Research Workshop   GLAS-19-4A
# 4442                     Global Local Teaching Workshop   GLAS-19-4B
#
#                                             description      source  credits  \
# ...

# %%
data.loc[data["fee"] > 0]
# Out:
#                                        title   identifier  \
# 9                                Photography   ART-033-HM
# 199                     Building Los Angeles    EA-174-HM
# 287   Digital Cinema: Experimental Animation    MS-170-HM
# 290                Introduction to Video Art    MS-182-HM
# 4173                      College Inside-Out  ORST-161-PZ
#
#                                             description      source  credits  \
# 9     Approaching the medium from an artistic perspe...  HarveyMudd      300
# 199   This course explores the complex network of ur...  HarveyMudd      300
# 287   Intermediate/advanced video course, exploring ...  HarveyMudd      300
# 290   This course is an introduction to video art th...  HarveyMudd      300
# 4173  College Inside-Out represents some of our grea...      Pitzer      100
#
#               instructors offered  \
# 9               [Fandell]
# 199              [Groves]
# 287   [Katherine Breeden]
# 290              [Mayeri]
# ...

# %%
len(data.loc[data["fee"] = 0])
# Out:
#   Input In [14]
#     len(data.loc[data["fee"] = 0])
#                              ^
# SyntaxError: invalid syntax
