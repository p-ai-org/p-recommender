# %%
import pandas as pd

df =pd.read_csv("courses_raw.csv", error_bad_lines=False)
# Out:
# b'Skipping line 6: expected 9 fields, saw 11\nSkipping line 11: expected 9 fields, saw 13\nSkipping line 41: expected 9 fields, saw 12\nSkipping line 42: expected 9 fields, saw 12\nSkipping line 43: expected 9 fields, saw 10\nSkipping line 78: expected 9 fields, saw 10\nSkipping line 110: expected 9 fields, saw 12\nSkipping line 119: expected 9 fields, saw 21\nSkipping line 140: expected 9 fields, saw 15\nSkipping line 156: expected 9 fields, saw 12\nSkipping line 163: expected 9 fields, saw 10\nSkipping line 166: expected 9 fields, saw 11\nSkipping line 183: expected 9 fields, saw 66\nSkipping line 195: expected 9 fields, saw 10\nSkipping line 199: expected 9 fields, saw 15\nSkipping line 225: expected 9 fields, saw 11\nSkipping line 226: expected 9 fields, saw 24\nSkipping line 231: expected 9 fields, saw 13\nSkipping line 235: expected 9 fields, saw 16\nSkipping line 238: expected 9 fields, saw 13\nSkipping line 248: expected 9 fields, saw 11\nSkipping line 262: expected 9 fields,
# ...

# %%
df.head(10)
# Out:
#     externalId classificationOfInstructionalProgramCode courseNumber  \
# 0  ABROAD   HM                                      NaN  ABROAD   HM
# 1  ABUS300A CG                                      NaN  ABUS300A CG
# 2  ABUS300C CG                                      NaN  ABUS300C CG
# 3  ABUS301  CG                                      NaN  ABUS301  CG
# 4  ABUS304A CG                                      NaN  ABUS304A CG
# 5  ABUS308  CG                                      NaN  ABUS308  CG
# 6  ABUS314  CG                                      NaN  ABUS314  CG
# 7  ABUS321A CG                                      NaN  ABUS321A CG
# 8  ABUS410  CG                                      NaN  ABUS410  CG
# 9  ACM 350  CG                                      NaN  ACM 350  CG
#
#                         courseTitle subjectAbbreviation departmentExternalId  \
# 0                   Semester Abroad                HMID                 HMID
# ...
