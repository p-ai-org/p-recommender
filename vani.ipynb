# %% [markdown]
# first, get libraries

# %%
import numpy
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('data.csv', error_bad_lines=False)

# %%
df #imported dataset
# Out:
#         externalId classificationOfInstructionalProgramCode courseNumber  \
# 0      ABROAD   HM                                      NaN  ABROAD   HM
# 1      ABUS300A CG                                      NaN  ABUS300A CG
# 2      ABUS300C CG                                      NaN  ABUS300C CG
# 3      ABUS301  CG                                      NaN  ABUS301  CG
# 4      ABUS304A CG                                      NaN  ABUS304A CG
# ...            ...                                      ...          ...
# 14595  XSPA190  CM                                      NaN  XSPA190  CM
# 14596  XSPA190A CM                                      NaN  XSPA190A CM
# 14597  XSPA190B CM                                      NaN  XSPA190B CM
# 14598  XSPA191  CM                                      NaN  XSPA191  CM
# 14599  XSPA192  CM                                      NaN  XSPA192  CM
#
#                             courseTitle subjectAbbreviation  \
# 0                       Semester Abroad                HMID
# 1          Intro to Art Market Dynamics                GACM
# 2              Contemporary Art Markets                GACM
# 3      Legal Foundations Creative Indus                GACM
# 4                  The Gallery Business                GACM
# ...                                 ...                 ...
# 14595          Senior Thesis in Spanish                MMOD
# 14596          Senior Thesis in Spanish                MMOD
# 14597          Senior Thesis in Spanish                MMOD
# 14598        Senior Research in Spanish                MMOD
# 14599          Senior Thesis in Spanish                MMOD
#
#       departmentExternalId institutionExternalId facilityExternalId  \
# 0                     HMID                    HM                 HM
# 1                     GACM                    CG                 CG
# 2                     GACM                    CG                 CG
# 3                     GACM                    CG                 CG
# 4                     GACM                    CG                 CG
# ...                    ...                   ...                ...
# 14595                 MMOD                    CM                 CM
# 14596                 MMOD                    CM                 CM
# 14597                 MMOD                    CM                 CM
# 14598                 MMOD                    CM                 CM
# 14599                 MMOD                    CM                 CM
#
#                                              description
# 0      Placeholder course for students studying abroa...
# 1                                                    NaN
# 2      A partner course to Art Market Dynamics, Conte...
# 3                                                    NaN
# 4      The Fundamentals of an Art Gallery is a detail...
# ...                                                  ...
# 14595                                                NaN
# 14596                                                NaN
# 14597                                                NaN
# 14598                                                NaN
# 14599                                                NaN
#
# [14600 rows x 9 columns]

# %%
#drop columns that aren't important: classificationOfInstructionalProgramCode, externalId (same as courseNumber), subjectAbbreviation, dsubjectAbbreviation, same as departmentExternalId, institutionExternalId (same as facilityExternalId)
df.drop(['externalId', 'classificationOfInstructionalProgramCode', 'subjectAbbreviation', 'departmentExternalId', 'institutionExternalId'],  axis=1, inplace=True)

# %%
#rename columns to be more helpful
df = df.rename(columns={"courseNumber": "Course Number", "courseTitle": "Course Title", "facilityExternalId": "Campus", "description" : "Description"})

# %%
#see all the na's 
df.isna().sum()
# Out:
# Course Number     117
# CourseTitle       125
# Campus            168
# Description      4077
# dtype: int64
